# %% [markdown]
# # RNN (Recurrent Neural Network)  - LSTM (Long Short-Term Memory) - GRU (Gated Recurrent Unit)

# %% [markdown]
# ## RNN

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM
from tensorflow.keras.models import Sequential



import warnings
warnings.filterwarnings('ignore')

# %%
# Generate example data 
X = np.random.rand(100,10, 1)
y = np.random.randint(0, 2, size=(100))
X.shape, y.shape
# Out:
# ((100, 10, 1), (100,))

# %%
# Define the model
model = Sequential([
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Comple the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=10, batch_size=32)

# evaluate the model 
loss, accuracy = model.evaluate(X, y)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# Epoch 1/10
# 4/4 [==============================] - 2s 22ms/step - loss: 0.7159 - accuracy: 0.4200
# Epoch 2/10
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6952 - accuracy: 0.4500
# Epoch 3/10
# 4/4 [==============================] - 0s 28ms/step - loss: 0.6906 - accuracy: 0.4900
# Epoch 4/10
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6903 - accuracy: 0.5300
# Epoch 5/10
# 4/4 [==============================] - 0s 28ms/step - loss: 0.6890 - accuracy: 0.5300
# Epoch 6/10
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6870 - accuracy: 0.5700
# Epoch 7/10
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6858 - accuracy: 0.5500
# Epoch 8/10
# 4/4 [==============================] - 0s 43ms/step - loss: 0.6849 - accuracy: 0.5400
# Epoch 9/10
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6848 - accuracy: 0.5400
# Epoch 10/10
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6849 - accuracy: 0.5200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6836 - accuracy: 0.5400
# Loss: 0.6836127638816833, Accuracy: 0.5400000214576721

# %% [markdown]
# # LSTM(Long Short-Term Memory)
# - LSTM is a special kind of RNN, Capable of learning long-term dependencies.

# %%
# Load flight data 
flight_data = sns.load_dataset('flights')

# Convert data to time series format
df = pd.DataFrame({'value': flight_data['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train, test = df.iloc[:train_size], df.iloc[train_size:]

# Normalize data
train_mean = train.mean()
train_std = train.std()
train = (train - train_mean) / train_std
test = (test - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train, seq_length)
X_test, y_test = to_sequences(test, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model
model = Sequential([
    LSTM(32, input_shape=(seq_length, 1)),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print(f"Loss: {loss}")

# Make predictions
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test.index[seq_length+1:], y_test, label='Actual')
plt.plot(test.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 2025-04-22 11:02:38.676902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:02:38.680516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:02:38.682920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-04-22 11:02:39.366360: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:02:39.371031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:02:39.374922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-04-22 11:02:41.236219: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:02:41.240751: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:02:41.244473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 4/4 [==============================] - 5s 45ms/step - loss: 0.9938
# Epoch 2/10
# 4/4 [==============================] - 0s 96ms/step - loss: 0.8458
# Epoch 3/10
# 4/4 [==============================] - 0s 85ms/step - loss: 0.7162
# Epoch 4/10
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6032
# Epoch 5/10
# 4/4 [==============================] - 0s 54ms/step - loss: 0.5089
# Epoch 6/10
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4180
# Epoch 7/10
# 4/4 [==============================] - 0s 56ms/step - loss: 0.3365
# Epoch 8/10
# 4/4 [==============================] - 0s 69ms/step - loss: 0.2710
# Epoch 9/10
# 4/4 [==============================] - 0s 74ms/step - loss: 0.2178
# Epoch 10/10
# 4/4 [==============================] - 0s 68ms/step - loss: 0.1856
# 2025-04-22 11:02:46.824274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:02:46.827923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:02:46.830521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 1s 723ms/step - loss: 1.7641
# Loss: 1.764089822769165
# 2025-04-22 11:02:47.708436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:02:47.711732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:02:47.713824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 1s 659ms/step

# %% [markdown]
# # let's build a simple RNN-based character-level text generator using a sample text. We'll use a sequence-to-sequence prediction approach to predict the next character in a sequence.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text))) # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars)) # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model
model = Sequential([
    LSTM(128, input_shape=(X.shape[1], X.shape[2])),
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50): # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=1)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# 2025-04-22 11:05:34.264706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025
# 5/5 [==============================] - 0s 50ms/step - loss: 2.6951
# Epoch 70/100
# 5/5 [==============================] - 0s 36ms/step - loss: 2.6954
# Epoch 71/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.6890
# Epoch 72/100
# 5/5 [==============================] - 0s 91ms/step - loss: 2.6849
# Epoch 73/100
# 5/5 [==============================] - 0s 100ms/step - loss: 2.6871
# Epoch 74/100
# 5/5 [==============================] - 0s 81ms/step - loss: 2.6897
# Epoch 75/100
# 5/5 [==============================] - 0s 91ms/step - loss: 2.6884
# Epoch 76/100
# 5/5 [==============================] - 0s 76ms/step - loss: 2.7097
# Epoch 77/100
# 5/5 [==============================] - 0s 99ms/step - loss: 2.7141
# Epoch 78/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.6867
# Epoch 79/100
# 5/5 [==============================] - 0s 85ms/step - loss: 2.6915
# Epoch 80/100
# 5/5 [==============================] - 0s 94ms/step - loss: 2.6871
# Epoch 81/100
# 5/5 [==============================] - 0s 85ms/step - loss: 2.6962
# Epoch 82/100
# 5/5 [==============================] - 0s 95ms/step - loss: 2.7061
# Epoch 83/100
# 5/5 [==============================] - 0s 75ms/step - loss: 2.6951
# Epoch 84/100
# 5/5 [==============================] - 0s 93ms/step - loss: 2.6873
# Epoch 85/100
# 5/5 [==============================] - 0s 74ms/step - loss: 2.6743
# Epoch 86/100
# 5/5 [==============================] - 0s 71ms/step - loss: 2.6736
# Epoch 87/100
# 5/5 [==============================] - 0s 68ms/step - loss: 2.6723
# Epoch 88/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.6735
# Epoch 89/100
# 5/5 [==============================] - 0s 105ms/step - loss: 2.6710
# Epoch 90/100
# 5/5 [==============================] - 1s 119ms/step - loss: 2.6711
# Epoch 91/100
# 5/5 [==============================] - 1s 111ms/step - loss: 2.6637
# Epoch 92/100
# 5/5 [==============================] - 1s 100ms/step - loss: 2.6662
# Epoch 93/100
# 5/5 [==============================] - 0s 53ms/step - loss: 2.6685
# Epoch 94/100
# 5/5 [==============================] - 1s 106ms/step - loss: 2.6671
# Epoch 95/100
# 5/5 [==============================] - 0s 72ms/step - loss: 2.6630
# Epoch 96/100
# 5/5 [==============================] - 0s 59ms/step - loss: 2.6680
# Epoch 97/100
# 5/5 [==============================] - 0s 63ms/step - loss: 2.6621
# Epoch 98/100
# 5/5 [==============================] - 0s 64ms/step - loss: 2.6713
# Epoch 99/100
# 5/5 [==============================] - 0s 51ms/step - loss: 2.6756
# Epoch 100/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6653
# Seed:
# " o world! t "
# 1/1 [==============================] - 1s 540ms/step
# 2025-04-22 11:06:24.968199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:06:24.971841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:06:24.973500: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 59ms/step

# %% [markdown]
# Here, we first convert our sample text into sequences of characters. Each sequence of characters (X) corresponds to a next character (y). The model is trained to predict y from X.
#
# After training, we take a random seed sequence and use the model to predict the next 50 characters. The output will show the initial seed and the generated text based on it.

# %% [markdown]
# # GRU (Gated Recurrent Unit) is a variation of LSTM. It has fewer parameters than LSTM, as it lacks an output gate.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU  # Note the change here
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model using GRU
model = Sequential([
    GRU(32, input_shape=(seq_length, 1)),  # Note the change here
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# 2025-04-22 11:07:41.413896: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:07:41.416748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:07:41.419239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/100
# 2025-04-22 11:07:42.169215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:07:42.175073: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:07:42.179460: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-04-22 11:07:43.683404: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:07:43.686365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:07:43.689573: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 4/4 [==============================] - 4s 78ms/step - loss: 1.0939
# Epoch 2/100
# 4/4 [==============================] - 0s 99ms/step - loss: 0.9372
# Epoch 3/100
# 4/4 [==============================] - 0s 77ms/step - loss: 0.8150
# Epoch 4/100
# 4/4 [==============================] - 0s 102ms/step - loss: 0.6858
# Epoch 5/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.5827
# Epoch 6/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.4920
# Epoch 7/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.4108
# Epoch 8/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3360
# Epoch 9/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2849
# Epoch 10/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2446
# Epoch 11/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2118
# Epoch 12/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1996
# Epoch 13/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1939
# Epoch 14/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.1918
# Epoch 15/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.1892
# Epoch 16/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.1850
# Epoch 17/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.1822
# Epoch 18/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1782
# Epoch 19/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1735
# Epoch 20/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1696
# Epoch 21/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1666
# Epoch 22/100
# 4/4 [==============================] - 0s 103ms/step - loss: 0.1639
# Epoch 23/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1619
# Epoch 24/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1593
# Epoch 25/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1570
# Epoch 26/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.
100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1027
# Epoch 74/100
# 4/4 [==============================] - 0s 99ms/step - loss: 0.1020
# Epoch 75/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0997
# Epoch 76/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0994
# Epoch 77/100
# 4/4 [==============================] - 0s 67ms/step - loss: 0.1002
# Epoch 78/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0974
# Epoch 79/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0974
# Epoch 80/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0988
# Epoch 81/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0980
# Epoch 82/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0959
# Epoch 83/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0955
# Epoch 84/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0949
# Epoch 85/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0942
# Epoch 86/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0928
# Epoch 87/100
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0931
# Epoch 88/100
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0931
# Epoch 89/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0934
# Epoch 90/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0924
# Epoch 91/100
# 4/4 [==============================] - 0s 93ms/step - loss: 0.0911
# Epoch 92/100
# 4/4 [==============================] - 0s 98ms/step - loss: 0.0889
# Epoch 93/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0886
# Epoch 94/100
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0916
# Epoch 95/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0903
# Epoch 96/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0869
# Epoch 97/100
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0875
# Epoch 98/100
# 4/4 [==============================] - 0s 94ms/step - loss: 0.0874
# Epoch 99/100
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0854
# Epoch 100/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0878
# 2025-04-22 11:08:14.848350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:08:14.851133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:08:14.853146: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 1s 537ms/step - loss: 0.6476
# Test Loss: 0.6475667953491211
# 2025-04-22 11:08:15.852773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-22 11:08:15.857287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-22 11:08:15.861258: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 1s 887ms/step

# %% [markdown]
# # GRU on Text

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense  # Import GRU instead of LSTM

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text)))  # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars))  # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model using GRU
model = Sequential([
    GRU(128, input_shape=(X.shape[1], X.shape[2])),  # Change LSTM to GRU here
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50):  # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char